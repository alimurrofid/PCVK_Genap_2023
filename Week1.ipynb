# %% [markdown]
# <a href="https://colab.research.google.com/github/alimurrofid/PCVK_Genap_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Langkah (Step) 1:
# Pada kode awal, beberapa library yang akan digunakan adalah: **numpy, pandas, cv2, skimage, PIL, matplotlib**
#
# * Numpy
# * Pandas
# * CV2
# * Skimage
# * Matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ### Langkah (Step) 2:
# Baca image dari URLs
#
# Pada langkah ini akan dilakukan pembacaan image dari URLs dan menampilkannya menggunakan OpenCV. Ada perbedaan ketika membuka image dalam RGB dan BGR. Channel Warna default untuk OpenCV adalah BGR.

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = [
        "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"
]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                              #read image
  image = cv.resize(image, (0,0), fx = 0.5, fy = 0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)      #convert color to RGB
  final_frame = cv.hconcat((image, image_2))          #concatenate image
  cv2_imshow(final_frame)                             #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ### Langkah (Step) 3
# melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# ### Langkah (Step) 4
# mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ### Pertanyaan
# 1. Karena Google Colab berbasis cloud sehingga lebih flexibel untuk digunakan karena tidak perlu instalasi dan konfigurasi Python, Jupyter Notebook, atau library tambahan secara manual.Karena sudah ada secara langsung di google colab sehingga kita dapat langsung mulai bekerja tanpa menghabiskan waktu untuk instalasi dan konfigurasi. Selain itu google colab juga dapat terkonfigurasi dengan github sehingga kode yang kita buat dapat kita simpan dengna mudah digithub apabila sewaktu waktu memerlukannya.
#
# 2. Library yang digunakan yaitu:
#
# * NumPy (Numerical Python): library Python yang digunakan untuk komputasi numerik. Ia menyediakan struktur data array dan operasi matematika yang efisien.
# * Pandas:  library untuk manipulasi dan analisis data.
# * OpenCV (cv2): library visi komputer yang digunakan untuk memproses gambar dan video.
# * scikit-image (skimage): ekstensi dari scikit-learn yang fokus pada pemrosesan gambar.
# * Matplotlib: library untuk visualisasi data.
#
# Pada praktikum kali ini kita tidak memerlukan semua library yang diimpor di atas melainkan hanya 2 library yang kita butuhkan yaitu skimage dan CV2 yang dimana kedua library tersebut dibutuhkan untuk mengolah citra
#
# 3. Kegunaan kode tersebut adalah untuk mengurangi ukuran gambar asli menjadi setengah ukuran dari ukuran aslinya baik secara horizontal maupun vertikal. Pengaruh apabila kode tersebut tidak ada adalah gambar akan tetap pada ukuran aslinya. Kode tersebut cukup penting agar mengurangi beban komputasi dalam pemrosesan. Tetapi hal ini juga perlu diingat mengubah ukuran gambar juga dapat mengurangi detail dari gambar tersebut.
#
# 4. Kode tersebut berguna untuk memberikan warna untuk garis tengah secara horizontal yang dimana kode [255,255,255] merupakan kode warna putih pada rgb.
#
# 5. Pixel adalah unit terkecil dalam gambar digital yang memiliki nilai warna. Resolusi gambar mengukur jumlah pixel dalam gambar per unit panjang. Resolusi tinggi memiliki lebih banyak pixel, memberikan detail dan kualitas gambar yang tinggi, cocok untuk cetakan dan fotografi. Resolusi rendah memiliki sedikit pixel, cocok untuk web dan tampilan layar kecil, namun dapat mengurangi kualitas saat diperbesar.

# %% [markdown]
# ### Tugas
# Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_4[x, int((lebar)/2)] = [0,0,0]

# membuat garis menyilang diagonal
cv.line(image_5, (0,0), (lebar, tinggi), (0,0,0))
cv.line(image_5, (lebar,0), (0, tinggi), (0,0,0))

final_frame = cv.hconcat((image_4, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
#garis sembarang

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (100,100), (200, 100), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
#kotak

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.rectangle(image_3, (230,140), (300, 200), (255,255,255), (-1))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ### Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73d2d1cd-0040-4a33-89a8-77ca9534d179" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73d2d1cd-0040-4a33-89a8-77ca9534d179">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('ktp_pcvk.png')

# %%
path = 'ktp_pcvk.png'
image_ktp = cv.imread(path)
image_ktp = cv.cvtColor(image_ktp,cv.COLOR_BGR2RGB)
plt.imshow(image_ktp)

# %%
color_yellow = (248,253,95)
color_black = (0,0,0)

image_ktp[40:60,120:340] = color_yellow
image_ktp[70:82,115:260] = color_black

plt.imshow(image_ktp)
